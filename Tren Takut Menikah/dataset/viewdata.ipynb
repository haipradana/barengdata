# %%
import pandas as pd

# %%
data = pd.read_csv('takut-nikah.csv')
data.head(100)  # Display the first 10 rows of the DataFrame
# Out:
#                             Name          Handle                 Timestamp  \
# 0                      resonance     @phosphenol  2025-07-13T17:28:15.000Z
# 1   El Wijangga (future!au 2033)     @histoir_El  2025-07-13T17:17:14.000Z
# 2                     ༘ cila ✿ 𓍯  @cilomilowilow  2025-07-13T17:12:27.000Z
# 3                            dee    @_tequilaaa_  2025-07-13T17:08:29.000Z
# 4              This is for 𝙼𝚎𝚒𝚍𝚢      @ahduoxian  2025-07-13T16:28:36.000Z
# ..                           ...             ...                       ...
# 95                             .      @nnnnnadfs  2025-07-12T18:46:42.000Z
# 96                   icikinda ia   @hanbyul_1207  2025-07-12T19:39:07.000Z
# 97                    Kilimansey   @sp4ce_cowboy  2025-07-12T19:59:06.000Z
# 98                          Sha!      @iivxaaahs  2025-07-12T22:42:03.000Z
# 99                            :v     @sasongko_n  2025-07-12T23:13:59.000Z
#
# ...

# %%
# cara ambil kolom hadnle dan content saja
data_filtered = data[['Handle', 'Content', 'Timestamp']]
data_filtered.head(10)  # Display the first 10 rows of the filtered DataFrame
# Out:
#              Handle                                            Content  \
# 0       @phosphenol  agak emosi\nkarena gue sendiri juga cowo yg mi...
# 1       @histoir_El  Ada. Gue yang sebelum nikah, pengen hidup sant...
# 2    @cilomilowilow  ih aku jg mau beli, tp tiap di supermarket tak...
# 3      @_tequilaaa_  gamau nikah ah takut ga bahagia, takut pny pas...
# 4        @ahduoxian  Iyap indo seimbang kok, orang pinternya juga g...
# 5       @phosphenol  agak emosi\nkarena gue sendiri juga cowo yg mi...
# 6           @cagvey  gue takut ditinggal nikah tmn gue, ntar gue ma...
# 7         @404slink   pengen nonton sore tpi takut pengen cepet" nikah
# 8  @kuliahsmpesabtu  Huhuhu buu semangat buat kita yang ngurus boci...
# 9        @exe__girl  sumpah gue makin takut klo gue hrs nikah dan p...
#
#                   Timestamp
# 0  2025-07-13T17:28:15.000Z
# 1  2025-07-13T17:17:14.000Z
# 2  2025-07-13T17:12:27.000Z
# 3  2025-07-13T17:08:29.000Z
# 4  2025-07-13T16:28:36.000Z
# ...

# %%
# convert timestamp to datetime indonesian
data['Timestamp'] = pd.to_datetime(data['Timestamp'], utc=True).dt.tz_convert('Asia/Jakarta')
data['Timestamp'] = data['Timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')
data_filtered['Timestamp'] = pd.to_datetime(data_filtered['Timestamp'], utc=True).dt.tz_convert('Asia/Jakarta')
data_filtered['Timestamp'] = data_filtered['Timestamp'].dt.strftime('%Y-%m-%d')

data_filtered.head(10)  # Display the first 10 rows of the filtered DataFrame with formatted timestamp
# Out:
# C:\Users\legion\AppData\Local\Temp\ipykernel_12860\626037410.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered['Timestamp'] = pd.to_datetime(data_filtered['Timestamp'], utc=True).dt.tz_convert('Asia/Jakarta')
# C:\Users\legion\AppData\Local\Temp\ipykernel_12860\626037410.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_filtered['Timestamp'] = data_filtered['Timestamp'].dt.strftime('%Y-%m-%d')
# ...
